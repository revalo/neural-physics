# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle
import tqdm
import random

# %% [markdown]
# Batch Size: 50
#
# Notes: Nothing Special

# %%
with open('losses.p', 'rb') as f:
    d = pickle.load(f)
    
plt.plot(d['vanilla'], label='vanilla')
plt.plot(d['uc'], label='uc')
plt.legend()

# %% [markdown]
# Batch Size: 2048
#
# Notes: Nothing Special

# %%
with open('losses.p', 'rb') as f:
    d = pickle.load(f)
    
plt.plot(d['vanilla'], label='vanilla')
plt.plot(d['uc'], label='uc')
plt.legend()

# %% [markdown]
# Batch Size: 2048
#
# UC Iteration: 0, So starting UC from the very start.
#
# Notes: Nothing Special

# %%
with open('losses.p', 'rb') as f:
    d = pickle.load(f)
    
plt.plot(d['vanilla'], label='vanilla')
plt.plot(d['uc'], label='uc')
plt.legend()

# %% [markdown]
# **Batch Size:** 50
#
# **UC Iteration:** 20
#
# **Mixing:** 0.5

# %%
with open('losses.p', 'rb') as f:
    d = pickle.load(f)
    
plt.plot(d['vanilla'], label='vanilla')
plt.plot(d['uc'], label='uc')
plt.legend()

# %% [markdown]
# **Batch Size:** 50
#
# **UC Iteration:** 20
#
# **Mixing:** 0.2

# %%
with open('losses.p', 'rb') as f:
    d = pickle.load(f)
    
plt.plot(d['vanilla'], label='vanilla')
plt.plot(d['uc'], label='uc')
plt.legend()

# %% [markdown]
# **Batch Size:** 50
#
# **UC Iteration:** 20
#
# **Mixing:** 0.1

# %%
with open('losses.p', 'rb') as f:
    d = pickle.load(f)
    
plt.plot(d['vanilla'], label='vanilla')
plt.plot(d['uc'], label='uc')
plt.legend()

# %% [markdown]
# **Batch Size:** 50
#
# **UC Iteration:** 20
#
# **Mixing:** 0.1
#
# **Epochs:** 5

# %%
with open('losses.p', 'rb') as f:
    d = pickle.load(f)
    
plt.plot(d['vanilla'], label='vanilla')
plt.plot(d['uc'], label='uc')
plt.legend()

# %% [markdown]
# **Batch Size:** 50
#
# **UC Iteration:** 20
#
# **Mixing:** 0.1
#
# **Epochs:** 1
#
# **Samples:** 300

# %%
with open('losses.p', 'rb') as f:
    d = pickle.load(f)
    
plt.plot(d['vanilla'], label='vanilla')
plt.plot(d['uc'], label='uc')
plt.legend()

# %% [markdown]
# **Batch Size:** 50
#
# **UC Iteration:** 20
#
# **Mixing:** 0.0 (Sanity Check!)
#
# **Epochs:** 1
#
# **Samples:** 100

# %%
with open('losses.p', 'rb') as f:
    d = pickle.load(f)
    
plt.plot(d['vanilla'], label='vanilla')
plt.plot(d['uc'], label='uc')
plt.legend()

# %% [markdown]
# **Batch Size:** 50
#
# **UC Iteration:** 20
#
# **SPLIT:** 0.2
#
# **Epochs:** 1
#
# **Samples:** 100

# %%
with open('losses.p', 'rb') as f:
    d = pickle.load(f)
    
plt.plot(d['vanilla'], label='vanilla')
plt.plot(d['uc'], label='uc')
plt.legend()

# %% [markdown]
# **Batch Size:** 2048
#
# **UC Iteration:** 20
#
# **SPLIT:** 0.2
#
# **Epochs:** 1
#
# **Samples:** 100

# %%
with open('losses2.p', 'rb') as f:
    d = pickle.load(f)
    
plt.plot(d['vanilla'], label='vanilla')
plt.plot(d['uc'], label='uc')
plt.legend()

# %% [markdown]
# **Batch Size:** 50
#
# **UC Iteration:** 20
#
# **SPLIT:** 0.5
#
# **Epochs:** 1
#
# **Samples:** 100

# %%
with open('losses2.p', 'rb') as f:
    d = pickle.load(f)
    
plt.plot(d['vanilla'], label='vanilla')
plt.plot(d['uc'], label='uc')
plt.legend()

# %% [markdown]
# **Batch Size:** 50
#
# **UC Iteration:** 20
#
# **SPLIT:** 0.1
#
# **Epochs:** 1
#
# **Samples:** 100

# %%
with open('losses2.p', 'rb') as f:
    d = pickle.load(f)
    
plt.plot(d['vanilla'], label='vanilla')
plt.plot(d['uc'], label='uc')
plt.legend()

# %% [markdown]
# **Batch Size:** 50
#
# **UC Iteration:** 20
#
# **SPLIT:** 0.05
#
# **Epochs:** 1
#
# **Samples:** 100

# %%
with open('losses.p', 'rb') as f:
    d = pickle.load(f)
    
plt.plot(d['vanilla'], label='vanilla')
plt.plot(d['uc'], label='uc')
plt.legend()

# %% [markdown]
# **Batch Size:** 50
#
# **UC Iteration:** 0
#
# **SPLIT:** 0.1
#
# **Epochs:** 1
#
# **Samples:** 100

# %%
with open('losses.p', 'rb') as f:
    d = pickle.load(f)
    
plt.plot(d['vanilla'], label='vanilla')
plt.plot(d['uc'], label='uc')
plt.legend()

# %% [markdown]
# **Batch Size:** 50
#
# **UC Iteration:** 5
#
# **SPLIT:** 0.1
#
# **Epochs:** 1
#
# **Samples:** 100

# %%
with open('losses.p', 'rb') as f:
    d = pickle.load(f)
    
plt.plot(d['vanilla'], label='vanilla')
plt.plot(d['uc'], label='uc')
plt.legend()

# %% [markdown]
# **Batch Size:** 50
#
# **UC Iteration:** 30
#
# **SPLIT:** 0.1
#
# **Epochs:** 1
#
# **Samples:** 100

# %%
with open('losses2.p', 'rb') as f:
    d = pickle.load(f)
    
plt.plot(d['vanilla'], label='vanilla')
plt.plot(d['uc'], label='uc')
plt.legend()

# %% [markdown]
# ### Train Each Data Point Addition From Scratch for `e` epochs.
#
# **Batch Size:** 50
#
# **UC Iteration:** 20
#
# **SPLIT:** 0.1
#
# **Epochs:** 20
#
# **Samples:** 100

# %%
with open('losses.p', 'rb') as f:
    d = pickle.load(f)

plt.plot(d['vanilla'], label='vanilla')
plt.plot(d['uc'], label='uc')
plt.legend()
